# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
crime_dataset = pd.read_csv("./US_Crime_Rate_2016.csv")
crime_dataset.head()
# Out:
#           City Population Violent crime  Murder and nonnegligent manslaughter  \
# 0     New York        NaN        47,821                                 319.0
# 1  Los Angeles        NaN        29,400                                 258.0
# 2      Chicago  2,707,064        25,532                                 492.0
# 3      Houston  2,355,606        25,257                                 275.0
# 4      Detroit    663,502        13,040                                 275.0
#
#    Rape1 Robbery Aggravated assault Property crime Burglary Larceny-theft  \
# 0  2,770  13,396             31,336        122,299    9,846       106,931
# 1  2,274   9,652             17,216         95,704   13,809        66,253
# 2  1,761   7,983             15,296         80,742    9,578        62,083
# 3  1,249   9,147             14,586        101,750   17,038        71,614
# 4    952   2,346              9,467         28,550    6,820        14,844
#
#   Motor vehicle theft Arson2
# ...

# %%
crime_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8105 entries, 0 to 8104
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   City                                  8105 non-null   object
#  1   Population                            8101 non-null   object
#  2   Violent crime                         8084 non-null   object
#  3   Murder and nonnegligent manslaughter  8102 non-null   float64
#  4   Rape1                                 8090 non-null   object
#  5   Robbery                               8104 non-null   object
#  6   Aggravated assault                    8103 non-null   object
#  7   Property crime                        8082 non-null   object
#  8   Burglary                              8092 non-null   object
#  9   Larceny-theft                         8098 non-null   object
#  10  Motor vehicle theft                   8102 non-null   object
# ...

# %%
crime_dataset.dropna(inplace=True)

# %%
crime_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7936 entries, 2 to 8083
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   City                                  7936 non-null   object
#  1   Population                            7936 non-null   object
#  2   Violent crime                         7936 non-null   object
#  3   Murder and nonnegligent manslaughter  7936 non-null   float64
#  4   Rape1                                 7936 non-null   object
#  5   Robbery                               7936 non-null   object
#  6   Aggravated assault                    7936 non-null   object
#  7   Property crime                        7936 non-null   object
#  8   Burglary                              7936 non-null   object
#  9   Larceny-theft                         7936 non-null   object
#  10  Motor vehicle theft                   7936 non-null   object
# ...

# %%
df = crime_dataset[["Murder and nonnegligent manslaughter", "Rape1", "Robbery", "Aggravat assault","Property crime","Burglary","Larceny-theft","Motor vehicle theft","Arson2"]]
# Out:
#   Input In [16]
#     df = crime_dataset[["Murder and nonnegligent manslaughter", "Rape1", "Robbery", "Aggravat assault","Property crime","Burglary","Larceny-theft","Motor vehicle theft","Arson2"]
#                       ^
# SyntaxError: '[' was never closed

# %%
df.head()
# Out:
#       City Population Violent crime  Murder and nonnegligent manslaughter  \
# 3  Houston  2,355,606        25,257                                 275.0
# 4  Detroit    663,502        13,040                                 275.0
# 5  Memphis    650,410        12,367                                 190.0
# 6  Phoenix  1,688,722        11,803                                 131.0
# 7   Dallas  1,363,295        11,764                                 198.0
#
#    Rape1 Robbery Aggravated assault Property crime Burglary Larceny-theft  \
# 3  1,249   9,147             14,586        101,750   17,038        71,614
# 4    952   2,346              9,467         28,550    6,820        14,844
# 5    468   2,432              9,277         39,860    7,833        27,981
# 6  1,139   3,197              7,336         55,974    9,471        39,427
# 7    797   4,400              6,369         45,279    9,210        25,812
#
#   Motor vehicle theft Arson2
# 3              13,098    485
# ...

# %%
normalized_crime_dataset=(crime_dataset-crime_dataset.min())/(crime_dataset.max()-crime_dataset.min())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     162 try:
# --> 163     result = func(left, right)
#     164 except TypeError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expressions.py:69, in _evaluate_standard(op, op_str, a, b)
#      68     _store_test_result(False)
# ---> 69 return op(a, b)
#
# ...
