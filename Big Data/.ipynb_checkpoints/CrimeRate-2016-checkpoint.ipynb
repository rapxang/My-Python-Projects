# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
crime_dataset = pd.read_csv("./US_Crime_Rate_2016.csv")
crime_dataset.head()
# Out:
#           City  Population  Violent crime  \
# 0     New York   8379043.0        47821.0
# 1  Los Angeles   8379043.0        29400.0
# 2      Chicago   8379043.0        25532.0
# 3      Houston   8379043.0        25257.0
# 4      Detroit   8379043.0        13040.0
#
#    Murder and nonnegligent manslaughter   Rape1  Robbery  Aggravated assault  \
# 0                                 319.0  2770.0  13396.0             31336.0
# 1                                 258.0  2274.0   9652.0             17216.0
# 2                                 492.0  1761.0   7983.0             15296.0
# 3                                 275.0  1249.0   9147.0             14586.0
# 4                                 275.0   952.0   2346.0              9467.0
#
#    Property crime  Burglary  Larceny-theft  Motor vehicle theft  Arson2
# 0        122299.0    9846.0       106931.0               5522.0     NaN
# 1         95704.0   13809.0        66253.0              15642.0  1672.0
# ...

# %%
crime_dataset.columns.tolist()
# Out:
# ['City',
#  'Population',
#  'Violent crime',
#  'Murder and nonnegligent manslaughter',
#  'Rape1',
#  'Robbery',
#  'Aggravated assault',
#  'Property crime',
#  'Burglary',
#  'Larceny-theft',
#  'Motor vehicle theft',
#  'Arson2']

# %%
crime_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8105 entries, 0 to 8104
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   City                                  8105 non-null   object
#  1   Population                            8103 non-null   float64
#  2   Violent crime                         8084 non-null   float64
#  3   Murder and nonnegligent manslaughter  8102 non-null   float64
#  4   Rape1                                 8090 non-null   float64
#  5   Robbery                               8104 non-null   float64
#  6   Aggravated assault                    8103 non-null   float64
#  7   Property crime                        8082 non-null   float64
#  8   Burglary                              8092 non-null   float64
#  9   Larceny-theft                         8098 non-null   float64
# ...

# %%
crime_dataset.dropna(inplace=True)

# %%
crime_dataset.head(10)
# Out:
#                                         City  Population  Violent crime  \
# 1                                Los Angeles   8379043.0        29400.0
# 2                                    Chicago   8379043.0        25532.0
# 3                                    Houston   8379043.0        25257.0
# 4                                    Detroit   8379043.0        13040.0
# 5                                    Memphis   8379043.0        12367.0
# 6                                    Phoenix   8379043.0        11803.0
# 7                                     Dallas   8379043.0        11764.0
# 8                                  Baltimore   8379043.0        11101.0
# 9                                San Antonio   8379043.0        11046.0
# 10  Las Vegas Metropolitan Police Department   8379043.0         8854.0
#
#     Murder and nonnegligent manslaughter   Rape1  Robbery  Aggravated assault  \
# 1                                  258.0  2274.0   9652.0             17216.0
# ...

# %%
crime_dataset['Violent crime'].unique()
# Out:
# array([2.9400e+04, 2.5532e+04, 2.5257e+04, 1.3040e+04, 1.2367e+04,
#        1.1803e+04, 1.1764e+04, 1.1101e+04, 1.1046e+04, 8.8540e+03,
#        7.8740e+03, 7.3760e+03, 7.0990e+03, 6.9820e+03, 5.9330e+03,
#        5.8860e+03, 5.7920e+03, 5.7910e+03, 5.5200e+03, 5.4590e+03,
#        5.2150e+03, 4.7510e+03, 4.6400e+03, 4.5590e+03, 4.4710e+03,
#        4.4510e+03, 4.3800e+03, 4.0680e+03, 3.9900e+03, 3.9640e+03,
#        3.9530e+03, 3.7750e+03, 3.6060e+03, 3.5810e+03, 3.2230e+03,
#        3.0090e+03, 2.8580e+03, 2.8500e+03, 2.8060e+03, 2.7990e+03,
#        2.6380e+03, 2.6160e+03, 2.6130e+03, 2.5710e+03, 2.5330e+03,
#        2.4400e+03, 2.4220e+03, 2.3690e+03, 2.1570e+03, 2.0660e+03,
#        2.0550e+03, 2.0460e+03, 1.9530e+03, 1.9460e+03, 1.8480e+03,
#        1.8350e+03, 1.7820e+03, 1.7660e+03, 1.7580e+03, 1.7520e+03,
#        1.7420e+03, 1.7110e+03, 1.6860e+03, 1.6220e+03, 1.5940e+03,
#        1.5550e+03, 1.5400e+03, 1.5200e+03, 1.4620e+03, 1.4530e+03,
# ...

# %%
boolean = crime_dataset['City'].duplicated().any()
print(boolean, end='\n\n')
# Out:
# True

# %%
crime_dataset.drop_duplicates(subset=['City'], inplace=True)
print(crime_dataset)
# Out:
#              City  Population  Violent crime  \
# 1     Los Angeles   8379043.0        29400.0
# 2         Chicago   8379043.0        25532.0
# 3         Houston   8379043.0        25257.0
# 4         Detroit   8379043.0        13040.0
# 5         Memphis   8379043.0        12367.0
# ...           ...         ...            ...
# 8079    Wild Rose       691.0            0.0
# 8080        Afton      2017.0            0.0
# 8081     Greybull      1857.0            0.0
# 8082        Hanna       766.0            0.0
# 8083       Lander      7489.0            0.0
#
#       Murder and nonnegligent manslaughter   Rape1  Robbery  \
# 1                                    258.0  2274.0   9652.0
# 2                                    492.0  1761.0   7983.0
# 3                                    275.0  1249.0   9147.0
# 4                                    275.0   952.0   2346.0
# 5                                    190.0   468.0   2432.0
# ...

# %%
crime_dataset.head()
# Out:
#           City  Population  Violent crime  \
# 1  Los Angeles   8379043.0        29400.0
# 2      Chicago   8379043.0        25532.0
# 3      Houston   8379043.0        25257.0
# 4      Detroit   8379043.0        13040.0
# 5      Memphis   8379043.0        12367.0
#
#    Murder and nonnegligent manslaughter   Rape1  Robbery  Aggravated assault  \
# 1                                 258.0  2274.0   9652.0             17216.0
# 2                                 492.0  1761.0   7983.0             15296.0
# 3                                 275.0  1249.0   9147.0             14586.0
# 4                                 275.0   952.0   2346.0              9467.0
# 5                                 190.0   468.0   2432.0              9277.0
#
#    Property crime  Burglary  Larceny-theft  Motor vehicle theft  Arson2
# 1         95704.0   13809.0        66253.0              15642.0  1672.0
# 2         80742.0    9578.0        62083.0               9081.0   416.0
# ...

# %%
crime_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6281 entries, 1 to 8083
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   City                                  6281 non-null   object
#  1   Population                            6281 non-null   float64
#  2   Violent crime                         6281 non-null   float64
#  3   Murder and nonnegligent manslaughter  6281 non-null   float64
#  4   Rape1                                 6281 non-null   float64
#  5   Robbery                               6281 non-null   float64
#  6   Aggravated assault                    6281 non-null   float64
#  7   Property crime                        6281 non-null   float64
#  8   Burglary                              6281 non-null   float64
#  9   Larceny-theft                         6281 non-null   float64
# ...

# %%
pd.value_counts(crime_dataset['City'])[:10]
# Out:
# Los Angeles            1
# Jones                  1
# Harrah                 1
# Dewey                  1
# Comanche               1
# Sugarcreek Township    1
# St. Clair Township     1
# South Bloomfield       1
# Sabina                 1
# Pepper Pike            1
# Name: City, dtype: int64

# %%
crime_dataset = pd.DataFrame(np.random.rand(10, 9), columns=["Murder and nonnegligent manslaughter", "Rape1", "Robbery", "Aggravat assault","Property crime","Burglary","Larceny-theft","Motor vehicle theft","Arson2"])

# %%
crime_dataset.plot.bar();

# %%
crime_dataset.plot.bar(stacked=True);

# %%
crime_dataset.plot.barh(stacked=True);

# %%
series = pd.Series(3 * np.random.rand(9), index=["Murder and nonnegligent manslaughter", "Rape1", "Robbery", "Aggravat assault","Property crime","Burglary","Larceny-theft","Motor vehicle theft","Arson2"], name="series")

# %%
series.plot.pie(figsize=(10, 10),autopct="%.2f");

# %%
crime_dataset.head()
# Out:
#    Murder and nonnegligent manslaughter     Rape1   Robbery  Aggravat assault  \
# 0                              0.118634  0.706203  0.989315          0.215177
# 1                              0.684278  0.705201  0.972414          0.084164
# 2                              0.730290  0.458147  0.275238          0.382467
# 3                              0.978689  0.961895  0.415544          0.553340
# 4                              0.675826  0.796200  0.411285          0.004401
#
#    Property crime  Burglary  Larceny-theft  Motor vehicle theft    Arson2
# 0        0.569317  0.840600       0.364458             0.149046  0.232512
# 1        0.634714  0.360883       0.303905             0.332099  0.365899
# 2        0.059071  0.197731       0.323649             0.243473  0.818861
# 3        0.754700  0.026128       0.480897             0.959836  0.550734
# 4        0.720305  0.218873       0.879906             0.385688  0.321313

# %%
# The number of part sand (n_cluster) we need to determine per work can be the same as the number of variables we need to concentrate on.

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 4)
kmeans
# Out:
# KMeans(n_clusters=4)

# %%
k_fit = kmeans.fit(crime_dataset)

# %%
# Let's create the chunks of the model to be fit

k_fit.n_clusters
# Out:
# 4

# %%
# create the centers of these sets

k_fit.cluster_centers_
# Out:
# array([[0.26876177, 0.83478673, 0.18313643, 0.75394585, 0.30954465,
#         0.92206935, 0.34593872, 0.42212519, 0.72370574],
#        [0.68640504, 0.59067288, 0.36394537, 0.31448269, 0.59094068,
#         0.38522185, 0.65432118, 0.23407348, 0.61258354],
#        [0.93775331, 0.89296306, 0.38160707, 0.59339337, 0.85762888,
#         0.24083461, 0.24996749, 0.94216583, 0.30399308],
#        [0.4014562 , 0.70570215, 0.98086438, 0.14967033, 0.6020157 ,
#         0.60074138, 0.33418141, 0.24057244, 0.2992056 ]])

# %%
# If I want to visualize, now let's reduce the set numbers to 2
kmeans = KMeans(n_clusters = 2)
k_fit = kmeans.fit(crime_dataset)

# %%
sets = k_fit.labels_

# %%
# Let's visualize the data we reduced to 2 sets.

plt.scatter(crime_dataset.iloc[:,0], crime_dataset.iloc[:,1], c = sets, s = 50, cmap = "viridis")

centers = k_fit.cluster_centers_                                 # We want to create 2 centers and show them on the visual.

plt.scatter(centers[:,0], centers[:,1], c = "black", s = 200, alpha = 0.5);

# %%
# Let us import 3D visualization. Otherwise it is necessary to download

from mpl_toolkits.mplot3d import Axes3D


# Let's create our sets again, this time it will be 3 dimensional variable

kmeans = KMeans(n_clusters = 3)
k_fit = kmeans.fit(crime_dataset)
sets = k_fit.labels_
centers = kmeans.cluster_centers_

# %%
plt.rcParams['figure.figsize'] = (16, 9)
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(crime_dataset.iloc[:, 0], crime_dataset.iloc[:, 1], crime_dataset.iloc[:, 2]);

# %%
# Let's look at the visualization of these sets and centers on the plot.

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(crime_dataset.iloc[:, 0], crime_dataset.iloc[:, 1], crime_dataset.iloc[:, 2], c=sets)
ax.scatter(centers[:, 0], centers[:, 1], centers[:, 2], 
           marker='*', 
           c='#050505', 
           s=1000);

# %%
# here it is appropriate to visualize the data to try to understand it.
# For example, 3 Assault (Assault) histogram looks like 3 peaks or accumulation.

crime_dataset.hist(figsize = (10,10));

# %%
# To provide cluster numbers and information about which states (observations) these numbers belong to
# If we want, we can take the model with 2 variables or 3 variables above, let's take the 3 ones

kmeans = KMeans(n_clusters = 3)
k_fit = kmeans.fit(crime_dataset)
sets = k_fit.labels_

# %%
# to see which set and index you have for the top 10 states

pd.DataFrame({"Violent crime" : crime_dataset.index, "Sets": sets})[0:15]
# Out:
#    Violent crime  Sets
# 0              0     1
# 1              1     1
# 2              2     0
# 3              3     2
# 4              4     1
# 5              5     0
# 6              6     0
# 7              7     0
# 8              8     1
# 9              9     2

# %%
# to see which set and index you have for the top 10 states

pd.DataFrame({"City" : crime_dataset.index, "Sets": sets})[0:15]
# Out:
#    City  Sets
# 0     0     1
# 1     1     1
# 2     2     0
# 3     3     2
# 4     4     1
# 5     5     0
# 6     6     0
# 7     7     0
# 8     8     1
# 9     9     2

# %%
# to look at the set number that each belongs to

crime_dataset["set_no"] = sets

crime_dataset.head()
# Out:
#    Murder and nonnegligent manslaughter     Rape1   Robbery  Aggravat assault  \
# 0                              0.118634  0.706203  0.989315          0.215177
# 1                              0.684278  0.705201  0.972414          0.084164
# 2                              0.730290  0.458147  0.275238          0.382467
# 3                              0.978689  0.961895  0.415544          0.553340
# 4                              0.675826  0.796200  0.411285          0.004401
#
#    Property crime  Burglary  Larceny-theft  Motor vehicle theft    Arson2  \
# 0        0.569317  0.840600       0.364458             0.149046  0.232512
# 1        0.634714  0.360883       0.303905             0.332099  0.365899
# 2        0.059071  0.197731       0.323649             0.243473  0.818861
# 3        0.754700  0.026128       0.480897             0.959836  0.550734
# 4        0.720305  0.218873       0.879906             0.385688  0.321313
#
#    set_no
# 0       1
# 1       1
# 2       0
# ...

# %%
# eger kume no 0 dan basliyorsa biz 1 den baslamasini istiyorsak soyle yapabiliriz

crime_dataset["set_no"] = crime_dataset["set_no"] + 1

crime_dataset.head()
# Out:
#    Murder and nonnegligent manslaughter     Rape1   Robbery  Aggravat assault  \
# 0                              0.118634  0.706203  0.989315          0.215177
# 1                              0.684278  0.705201  0.972414          0.084164
# 2                              0.730290  0.458147  0.275238          0.382467
# 3                              0.978689  0.961895  0.415544          0.553340
# 4                              0.675826  0.796200  0.411285          0.004401
#
#    Property crime  Burglary  Larceny-theft  Motor vehicle theft    Arson2  \
# 0        0.569317  0.840600       0.364458             0.149046  0.232512
# 1        0.634714  0.360883       0.303905             0.332099  0.365899
# 2        0.059071  0.197731       0.323649             0.243473  0.818861
# 3        0.754700  0.026128       0.480897             0.959836  0.550734
# 4        0.720305  0.218873       0.879906             0.385688  0.321313
#
#    set_no
# 0       2
# 1       2
# 2       1
# ...

# %%
# making the matrix look a little prettier
import seaborn as sns
corr_matrix = crime_dataset.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, 
            annot=True, 
            linewidths=0.5, 
            fmt= ".2f", 
            cmap="YlGnBu");
